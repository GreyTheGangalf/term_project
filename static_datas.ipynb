# %%
import pandas as pd

from global_macro import global_macro_df

# %%
sp_table = pd.read_csv('sp500_table.csv')
sp_table
# Out:
#             Date Ticker  Total Revenue  Gross Profit  Operating Income  \
# 0     2025-12-31    MMM   2.494800e+10  9.957000e+09      4.791000e+09
# 1     2024-12-31    MMM   2.457500e+10  1.012800e+10      4.822000e+09
# 2     2023-12-31    MMM   2.461000e+10  9.627000e+09     -1.072500e+10
# 3     2022-12-31    MMM   2.616100e+10  1.030800e+10      1.916000e+09
# 4     2021-12-31    MMM            NaN           NaN               NaN
# ...          ...    ...            ...           ...               ...
# 2484  2021-12-31    ZTS            NaN           NaN               NaN
# 2485  2022-12-31    ZTS   8.080000e+09  5.626000e+09      2.928000e+09
# 2486  2023-12-31    ZTS   8.544000e+09  5.983000e+09      3.069000e+09
# 2487  2024-12-31    ZTS   9.256000e+09  6.537000e+09      3.392000e+09
# 2488  2025-12-31    ZTS   9.467000e+09  6.801000e+09      3.597000e+09
#
#         Net Income  Diluted EPS  Research And Development  Total Assets  \
# ...

# %%
global_macro = pd.read_csv('global_macro_df.csv')
global_macro
# Out:
#             Date  Policy_Rate  Inflation_CPI  M2_Money_Supply  \
# 0     1947-01-01          NaN         21.480              NaN
# 1     1947-02-01          NaN         21.620              NaN
# 2     1947-03-01          NaN         22.000              NaN
# 3     1947-04-01          NaN         22.000              NaN
# 4     1947-05-01          NaN         21.950              NaN
# ...          ...          ...            ...              ...
# 3566  2026-06-01          NaN            NaN              NaN
# 3567  2026-06-01          NaN            NaN          23155.2
# 3568  2026-06-01          NaN        332.568              NaN
# 3569  2026-06-01         3.63            NaN              NaN
# 3570  2026-07-01         3.63            NaN              NaN
#
#       Unemployment_Rate
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 3566                4.2
# ...
